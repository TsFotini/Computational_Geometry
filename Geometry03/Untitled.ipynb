# %% [markdown]
# # Computational Geometry

# %% [markdown]
# ## Programming Assignments II

# %% [markdown]
# #### Exercise 1
# Compute Voronoi diagrams of diﬀerent sets of vertices of your choice using the routine Voronoi (and its companion voronoi plot 2d for visualization) from the module scipy.spatial. Plot your results.

# %% [markdown]
# In order to understand the code , we need to introduce the definition of a Voronoi diagram. A Voronoi diagram is a partition of a plane into regions close to each of a given set of objects.For each seed there is a corresponding region consisting of all points of the plane closer to that seed than to any other. These regions are called Voronoi cells. The Voronoi diagram of a set of points is dual to its Delaunay triangulation.
# The pointlist variable, is actually the list of coordinates of points to construct a convex hull from. Below we present another example of a new list of points.

# %%
import numpy as np 
from scipy.spatial import Voronoi, voronoi_plot_2d
import matplotlib.pyplot as plt

# %%
#(0, 3) (0, 0) (3, 0) (3, 3)
pointlist = np.array([[0,3], [0,0], [3,0], [3,3]])
vor = Voronoi(pointlist)
voronoi_plot_2d(vor)
plt.show()

# %% [markdown]
# Secondly, we will try to generate a list of random points and plot a Voronoi Diagram.

# %%
from random import randint
number_of_points = randint(4,80)
print("This is how many points we will generated:",number_of_points)
dimension = 2
points = np.random.randint(number_of_points, size=(number_of_points, dimension))
print(points)
# Out:
# This is how many points we will generated: 74
# [[46 49]
#  [58 49]
#  [35 10]
#  [69 70]
#  [ 7 73]
#  [17 31]
#  [53  0]
#  [64  7]
#  [16 60]
#  [ 1 13]
#  [45  6]
#  [68 61]
#  [19  6]
#  [25 45]
#  [45 67]
#  [47 51]
#  [42 12]
#  [19 13]
#  [21 25]
#  [15 60]
#  [22 52]
#  [70  2]
#  [ 4 40]
#  [28  4]
#  [63 14]
#  [58 13]
#  [23  1]
#  [23 19]
#  [16  3]
#  [ 8 43]
#  [73 54]
#  [19 37]
#  [28 46]
#  [20 21]
#  [57 41]
#  [39 66]
#  [50 32]
#  [58 67]
#  [ 2 30]
#  [57 38]
#  [36  1]
#  [ 0 29]
#  [51 23]
#  [16 60]
#  [36 69]
#  [70 34]
#  [11 12]
#  [11 36]
#  [45 55]
#  [47  9]
#  [ 7 72]
#  [10 43]
#  [ 7 54]
#  [68 53]
#  [65 23]
#  [ 7 41]
#  [32 50]
#  [51 44]
#  [24 73]
#  [16 10]
#  [17 19]
#  [51 19]
#  [33 73]
#  [36 31]
#  [50  5]
#  [ 7  5]
#  [14 39]
#  [70 29]
#  [40  8]
#  [31 32]
#  [73 62]
#  [15 15]
#  [29 42]
#  [41 60]]

# %%
# generate Voronoi tessellation
vor2 = Voronoi(points)
voronoi_plot_2d(vor2,line_colors='red')
plt.show()

# %%
vor2.vertices #Coordinates of the Voronoi vertices.
# Out:
# array([[ 288.16666667,   15.5       ],
#        [  80.1       ,   15.5       ],
#        [  61.67073171,   30.85772358],
#        [  69.72727273,   65.36363636],
#        [  71.2       ,   58.        ],
#        [  29.5       , -254.5       ],
#        [  29.5       ,   -4.16666667],
#        [  33.02173913,    5.22463768],
#        [  36.12790698,    5.56976744],
#        [   9.        ,   48.63636364],
#        [   1.18085106,   47.92553191],
#        [  78.84482759,   15.20114943],
#        [  59.29069767,   19.54651163],
#        [ 154.83333333,   31.5       ],
#        [  62.11538462,   31.5       ],
#        [  59.4       ,   58.        ],
#        [  64.1875    ,   65.97916667],
#        [  53.73404255,  104.30851064],
#        [  23.63513514,    5.60810811],
#        [  24.5       ,    9.5       ],
#        [  33.56896552,   20.59195402],
#        [  27.16666667,   12.05555556],
#        [  27.        ,   12.        ],
#        [ -69.16666667,   63.        ],
#        [-131.64285714,   72.5       ],
#        [ -78.87894737,   63.91052632],
#        [  28.5       ,   66.5       ],
#        [  15.5       ,   72.5       ],
#        [  39.39830508,   40.88983051],
#        [  15.6971831 ,   69.14788732],
#        [  27.05319149,   62.15957447],
#        [  24.01136364,   31.34090909],
#        [  34.79166667,   37.95833333],
#        [  31.71917808,   22.59589041],
#        [  28.93243243,   24.31081081],
#        [  73.14864865,   11.87837838],
#        [  61.16666667,   10.16666667],
#        [  61.81958763,   -1.71649485],
#        [  57.02631579,    5.81578947],
#        [  57.        ,    6.        ],
#        [  35.78965517,   20.4862069 ],
#        [  40.88396624,   22.09493671],
#        [  38.41666667,   11.29166667],
#        [  43.34251969,   26.70472441],
#        [  58.5       ,   29.16666667],
#        [  58.        ,   28.33333333],
#        [  58.19642857,   20.3125    ],
#        [  58.        ,   21.        ],
#        [  42.22222222,   21.        ],
#        [  72.42783505,   43.86082474],
#        [  69.8       ,   57.        ],
#        [  60.6       ,   57.        ],
#        [   9.        ,   41.25      ],
#        [  10.19565217,   39.45652174],
#        [   4.5       ,   43.5       ],
#        [   6.76315789,   36.71052632],
#        [  23.96341463,   32.01219512],
#        [  25.68181818,   36.13636364],
#        [   9.64814815,   28.27777778],
#        [  -2.27777778,   36.05555556],
#        [   5.5       ,   34.5       ],
#        [   5.10606061,   21.28787879],
#        [ -18.5       , -131.        ],
#        [  19.61111111,    2.38888889],
#        [  19.5       ,    9.5       ],
#        [  16.33333333,   12.66666667],
#        [  15.5       ,    6.5       ],
#        [  12.05555556,    6.5       ],
#        [  23.07142857,   22.35714286],
#        [  38.53478261,   42.98695652],
#        [  42.5       ,   77.        ],
#        [  51.5       ,   95.        ],
#        [  50.96153846,   37.96153846],
#        [  41.64285714,   39.64285714],
#        [  42.48802395,   38.66766467],
#        [  14.10377358,   50.02830189],
#        [  27.09345794,   62.07009346],
#        [  28.91414141,   60.57070707],
#        [   6.5       ,   63.        ],
#        [  15.5       ,   69.        ],
#        [  14.4245283 ,   52.43396226],
#        [  15.5       ,   53.375     ],
#        [  43.25      ,    8.875     ],
#        [  40.84883721,    2.87209302],
#        [  44.27659574,   -3.29787234],
#        [  46.27272727,   -0.63636364],
#        [  15.13636364,   34.86363636],
#        [  15.26470588,   34.91176471],
#        [  10.5       ,   39.5       ],
#        [  17.07142857,   46.07142857],
#        [   9.86666667,   25.        ],
#        [   7.2195122 ,   21.3902439 ],
#        [  14.5       ,   25.        ],
#        [  15.7       ,   24.2       ],
#        [  18.        ,   16.        ],
#        [  20.        ,   16.66666667],
#        [  20.        ,   17.75      ],
#        [  11.84883721,    6.87209302],
#        [  13.97826087,   12.19565217],
#        [   5.78378378,   10.33783784],
#        [   6.86842105,   21.18421053],
#        [   7.13636364,   21.31818182],
#        [  51.5       ,   61.        ],
#        [  54.26923077,   58.        ],
#        [  39.10240964,   50.93373494],
#        [  55.38235294,   45.26470588],
#        [  52.5       ,   39.5       ],
#        [  64.57692308,   39.5       ],
#        [  65.81578947,   43.96052632],
#        [  66.5944206 ,   43.24678112],
#        [  32.9       ,   45.1       ],
#        [  27.        ,   51.        ],
#        [  47.67647059,    6.38235294],
#        [  43.64285714,    9.07142857],
#        [  47.06451613,   14.77419355],
#        [  52.78571429,   10.21428571],
#        [  51.81914894,   12.87234043],
#        [  18.69230769,   43.48076923],
#        [  17.38421053,   45.87894737],
#        [  25.25      ,   49.25      ],
#        [  24.        ,   39.5       ],
#        [  27.11538462,   43.65384615],
#        [  53.75      ,   56.875     ],
#        [  43.25      ,   51.625     ],
#        [  52.39855072,   49.44202899],
#        [  50.16666667,   48.16666667],
#        [  30.2826087 ,   60.2826087 ],
#        [  41.21428571,   71.21428571],
#        [  47.375     ,   61.        ],
#        [  42.44736842,   63.81578947],
#        [  38.08823529,   53.57058824],
#        [  30.95945946,   59.98648649]])

# %%
vor2.regions #Indices of the Voronoi vertices forming each Voronoi region. -1 indicates vertex outside the Voronoi diagram.
# Out:
# [[],
#  [4, -1, 3],
#  [14, 2, 1, 0, 13],
#  [17, -1, 3, 16],
#  [22, 19, 18, 6, 7, 21],
#  [27, 24, -1],
#  [30, 26, -1, 27, 29],
#  [39, 36, 35, 37, 38],
#  [36, 12, 11, 35],
#  [37, -1, 0, 1, 11, 35],
#  [42, 8, 7, 21, 20, 40],
#  [47, 45, 44, 2, 1, 11, 12, 46],
#  [48, 41, 43, 45, 47],
#  [50, 4, -1, 0, 13, 49],
#  [51, 15, 16, 3, 4, 50],
#  [55, 53, 52, 54],
#  [54, 10, 9, 52],
#  [57, 32, 33, 34, 31, 56],
#  [60, 55, 54, 10, 23, 25, 59],
#  [61, -1, 24, 25, 59],
#  [63, 18, 6, 5, -1, 62],
#  [66, 63, 18, 19, 64],
#  [67, 62, 63, 66],
#  [71, 17, -1, 26, 70],
#  [74, 43, 45, 44, 72],
#  [74, 43, 41, 40, 20, 33, 32, 28, 73],
#  [81, 79, 78, 80],
#  [79, 29, 27, 24, 25, 23, 78],
#  [80, 75, 9, 10, 23, 78],
#  [81, 76, 30, 29, 79],
#  [83, 8, 42, 82],
#  [84, 5, 6, 7, 8, 83],
#  [85, 38, 37, -1, 5, 84],
#  [88, 53, 55, 60, 58, 86],
#  [89, 75, 9, 52, 53, 88],
#  [96, 93, 92, 90, 91, 94, 95],
#  [92, 31, 56, 87, 86, 58, 90],
#  [93, 68, 34, 31, 92],
#  [96, 68, 93],
#  [95, 22, 19, 64, 65, 94],
#  [96, 68, 34, 33, 20, 21, 22, 95],
#  [101, 98, 97, 99, 100],
#  [98, 65, 64, 66, 67, 97],
#  [99, -1, 62, 67, 97],
#  [101, 91, 94, 65, 98],
#  [100, 61, -1, 99],
#  [101, 91, 90, 58, 60, 59, 61, 100],
#  [103, 15, 16, 17, 71, 102],
#  [109, 107, 106, 105, 108],
#  [107, 14, 2, 44, 72, 106],
#  [109, 49, 13, 14, 107],
#  [109, 49, 50, 51, 108],
#  [116, 114, 113, 112, 115],
#  [113, 82, 83, 84, 85, 112],
#  [115, 39, 38, 85, 112],
#  [114, 48, 41, 40, 42, 82, 113],
#  [116, 46, 47, 48, 114],
#  [116, 46, 12, 36, 39, 115],
#  [121, 119, 118, 117, 120],
#  [118, 89, 88, 86, 87, 117],
#  [120, 57, 56, 87, 117],
#  [119, 111, 77, 76, 81, 80, 75, 89, 118],
#  [121, 110, 111, 119],
#  [121, 110, 69, 28, 32, 57, 120],
#  [125, 123, 122, 124],
#  [124, 105, 108, 51, 15, 103, 122],
#  [125, 73, 28, 69, 104, 123],
#  [125, 73, 74, 72, 106, 105, 124],
#  [127, 70, 26, 30, 76, 77, 126],
#  [131, 129, 128, 130],
#  [130, 104, 123, 122, 103, 102, 128],
#  [129, 127, 70, 71, 102, 128],
#  [131, 126, 127, 129],
#  [131, 126, 77, 111, 110, 69, 104, 130]]

# %%
pr = vor2.point_region
pr #Indices of the Voronoi vertices forming each Voronoi region. -1 indicates vertex outside the Voronoi diagram.
# Out:
# array([66, 65, 10,  3,  5, 36, 32,  7, 29, 45, 53, 14, 21, 58, 71, 64, 55,
#        39, 37, 26, 61,  9, 18,  4,  8, 57, 20, 40, 22, 16, 13, 60, 62, 38,
#        48, 72, 24, 47, 46, 49, 31, 19, 12, 29, 68, 50, 41, 33, 70, 52, 27,
#        34, 28, 51, 11, 15, 73, 67,  6, 42, 35, 56, 23, 25, 54, 43, 59,  2,
#        30, 17,  1, 44, 63, 69], dtype=int64)

# %%
import matplotlib as mpl
import matplotlib.cm as cm

colors_dictionary = ['blue','green','red','gray','magenta','yellow','purple','burlywood','cyan','pink','brown']
colors = []
voronoi_plot_2d(vor2, show_points=True, show_vertices=False, s=1)
for r in range(len(pr)):
    if len(colors) == 0:
        colors = colors_dictionary.copy()
    region = vor2.regions[pr[r]]
    if not -1 in region:
        polygon = [vor2.vertices[i] for i in region]
        plt.fill(*zip(*polygon), color=colors[0])
        colors.pop(0)
plt.show()

# %% [markdown]
# Notice that some cells are not colored and this is because one of their vertex is outside the current Voronoi diagram. This particular vertex is indicated with the value -1.

# %% [markdown]
# #### Exercise 2
# Using the routine Delaunay in the module scipy.spatial compute the Delaunay triangulation of diﬀerent sets of vertices of your choice and plot your results.

# %% [markdown]
# The first example of data we give, is a set of points that are colinear. For a set of points on the same line there is NO Delaunay triangulation as we can see below.

# %%
from scipy.spatial import Delaunay
straight_line_points = np.array([[0,0], [1,1], [2,2], [3,3]])
plt.triplot(straight_line_points[:,0], straight_line_points[:,1], tri.simplices)
plt.plot(straight_line_points[:,0], straight_line_points[:,1], 'o')
plt.show()

# %% [markdown]
# So the next step, is to insert a set of points that are not colinear. Furthermore this particular set is a set of points that constructs a convex hull.

# %%
plist = np.array([[0,3], [0,0], [3,0], [3,3]])
tri = Delaunay(plist)
plt.triplot(plist[:,0], plist[:,1], tri.simplices)
plt.plot(plist[:,0], plist[:,1], 'o')
plt.show()

# %% [markdown]
# If we desire to add one more data point to our initial set the results will be those presented below.

# %%
def delaunay_(plist):
    tri = Delaunay(plist)
    plt.triplot(plist[:,0], plist[:,1], tri.simplices)
    plt.plot(plist[:,0], plist[:,1], 'o')
    plt.show() 
    return tri
new_element = np.array([8,8])
new_plist = np.vstack((plist, new_element))
new_plist
# Out:
# array([[0, 3],
#        [0, 0],
#        [3, 0],
#        [3, 3],
#        [8, 8]])

# %%
delaunay_(new_plist)

# %%
delaunay_(points) #the random points that we had generated in Exercise 1

# %% [markdown]
# The Delaunay routine can be used for multi-dimensional data. To prove this, we present an example where the dataset that we are going to use is for 3D points. The output is a polyhedron constructed in a three dimensional space. What is important to mention about this routine is that, if you give 3D points it returns 3D objects. Give it 2D points and it returns 2D objects.

# %%
u = np.array([0,0,0.5,2,2]) 
v = np.array([0,2,1,0,2])
x = u
y = v
z = np.array([0,0,3,0,0])
tri = Delaunay(np.array([u,v]).T)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.tri as mtri
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, projection='3d')
ax.plot_trisurf(x, y, z, triangles=tri.simplices,color=colors_dictionary[8])
plt.show()

# %%
import random
dim = 7
u = []
v = []
z = []
def random_generation_of_nums(dim):
    if dim < 3:
        print("Error!")
        return 
    u = []
    for i in range(0,dim):
        new_num = round(random.random(), 2)
        u.append(new_num)
    return u
u = random_generation_of_nums(dim)
u = np.array(u) 
v = random_generation_of_nums(dim)
v = np.array(v)
x = u
y = v
z = random_generation_of_nums(dim)
z = np.array(z)
tri = Delaunay(np.array([u,v]).T)

# %%
u
# Out:
# array([0.03, 0.35, 0.29, 0.3 , 0.32, 0.21, 0.89])

# %%
v
# Out:
# array([0.04, 0.23, 0.35, 0.12, 0.54, 0.9 , 0.83])

# %%
z
# Out:
# array([0.73, 0.86, 0.01, 0.46, 0.19, 0.49, 0.44])

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, projection='3d')
ax.plot_trisurf(x, y, z, triangles=tri.simplices,color=colors_dictionary[9])
plt.show()

# %% [markdown]
# #### Exercise 3

# %% [markdown]
# Compute the shortest path of diﬀerent set of vertices of your choice in a triangulation. By a path in this setting, we mean a chain of edges of this triangulation. Use the methods in the package scipy.sparse.csgraph.

# %% [markdown]
# This module uses graphs which are stored in a matrix format. A graph with N nodes can be represented by an (N x N) adjacency matrix G. If there is a connection from node i to node j, then G[i, j] = w, where w is the weight of the connection. For nodes i and j which are not connected, the value depends on the representation.

# %%
pointlist = np.array([[0,3], [0,0], [3,0]])

# %%
tri = delaunay_(pointlist)

# %% [markdown]
# The structure of the triangulation is encoded in the following way: the simplices attribute contains the indices of the points in the points array that make up the triangle.

# %% [markdown]
# #### Exercise 4

# %% [markdown]
# Experiment yourself with the .encloses point and .encloses methods of the sympy.geometry module usingf polygons or circles to check if they contain certain points of your choice. Do the same with contains point or contains points from the Path class from the libraries of matplotlib.path

# %%
from sympy import Point, Polygon, RegularPolygon, Circle
p1, p2, p3, p4 = [[0,3], [0,0], [3,0], [3,3]]
pol = Polygon(p1, p2, p3, p4)
pol
# Out:
# Polygon(Point2D(0, 3), Point2D(0, 0), Point2D(3, 0), Point2D(3, 3))

# %%
pol.encloses_point(Point(2, 1))
# Out:
# True

# %%
from matplotlib.path import Path 
p2D = [[0,3], [0,0], [3,0], [3,3]]
path = Path(p2D) 
path.contains_point([2, 1])
# Out:
# True

# %% [markdown]
# We notice that the results are the same for points of a convex hull, and when searching for the same point [2,1].

# %%
path = Path(points) #using the points that were randomly generated in exercise 1
a = randint(0,80)
b = randint(0,80)
print("Point to be searched is : (",a,",",b,")")
path.contains_point([a,b])
# Out:
# Point to be searched is : ( 53 , 58 )
# False

# %%
c = Circle(Point(0,0), 22) #center(0,0) radius 11
c
# Out:
# Circle(Point2D(0, 0), 22)

# %%
c.encloses_point(Point(0, 0))
# Out:
# True

# %%
c.encloses_point(Point(a, b))
# Out:
# False

# %%
e = Ellipse((0, 0), a, b)
e
# Out:
# Ellipse(Point2D(0, 0), 53, 58)

# %%
e.encloses_point(Point(0, 0))
# Out:
# True

# %%
e.encloses_point(Point(a, b))
# Out:
# False
